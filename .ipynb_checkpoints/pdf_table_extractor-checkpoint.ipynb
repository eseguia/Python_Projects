# %%
import camelot as cm
import pandas as pd
import seaborn as sns

# %%
input_pdf = cm.read_pdf("COVID-19MorbidityMortalityRaceEthnicityLanguageWAState.pdf", flavor = "stream", pages = "31")
input_pdf
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-c2a1a8569582> in <module>
# ----> 1 input_pdf = cm.read_pdf("COVID-19MorbidityMortalityRaceEthnicityLanguageWAState.pdf", flavor = "stream", pages = "31")
#       2 input_pdf
#
# ~\anaconda3\lib\site-packages\camelot\io.py in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     109
#     110         validate_input(kwargs, flavor=flavor)
# --> 111         p = PDFHandler(filepath, pages=pages, password=password)
#     112         kwargs = remove_extra(kwargs, flavor=flavor)
#     113         tables = p.parse(
#
# ~\anaconda3\lib\site-packages\camelot\handlers.py in __init__(self, filepath, pages, password)
#      48             if sys.version_info[0] < 3:
#      49                 self.password = self.password.encode("ascii")
# ---> 50         self.pages = self._get_pages(self.filepath, pages)
#      51
#      52     def _get_pages(self, filepath, pages):
#
# ~\anaconda3\lib\site-packages\camelot\handlers.py in _get_pages(self, filepath, pages)
#      71             page_numbers.append({"start": 1, "end": 1})
#      72         else:
# ---> 73             instream = open(filepath, "rb")
#      74             infile = PdfFileReader(instream, strict=False)
#      75             if infile.isEncrypted:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'COVID-19MorbidityMortalityRaceEthnicityLanguageWAState.pdf'

# %%
for n in input_pdf:
    print(n)
# Out:
# <Table shape=(21, 4)>

# %%
input_pdf[0].df
# Out:
#                                                     0                       1  \
# 0   Table 4. Confirmed or probable COVID-19 case c...
# 1                                     language spoken
# 2
# 3
# 4                                            Language  Case Count  % of Cases
# 5
# 6
# 7                                           All Cases                 631,023
# 8                                    Unknown Language                 400,072
# 9                                      Known Language                 230,951
# 10                                            English                 191,905
# 11                                            Spanish                  32,665
# 12                                        Marshallese                     333
# 13                                         Vietnamese                   1,134
# 14                                            Russian                   1,403
# 15                                      Chinese (all)                     395
# 16                                          Ukrainian                     269
# 17                                             Somali                     336
# 18                                            Tagalog                     149
# 19                                            Amharic                     190
# 20                                              Other                   2,172
#
#          2                3
# 0
# 1
# 2                   % of WA
# 3           Population with
# 4
# 5           Limited English
# 6              Proficiency*
# 7   100.0%
# 8    63.4%
# 9    36.6%
# 10  83.1*%
# 11  14.1*%              6.4
# 12   0.1*%              0.1
# 13   0.5*%              0.5
# 14   0.6*%              0.3
# 15   0.2*%              0.3
# 16   0.1*%              0.2
# 17   0.1*%              0.1
# 18   0.1*%              0.1
# 19   0.1*%              0.1
# 20   0.9*%

# %%
df = input_pdf[0].df.loc[11:21, 0:3]
df = df.reset_index(drop = True)
df.columns = ["Language","Case Count","% of Cases","% Limited English Proficiency"]
df
# Out:
#         Language Case Count % of Cases % Limited English Proficiency
# 0        Spanish     32,665     14.1*%                           6.4
# 1    Marshallese        333      0.1*%                           0.1
# 2     Vietnamese      1,134      0.5*%                           0.5
# 3        Russian      1,403      0.6*%                           0.3
# 4  Chinese (all)        395      0.2*%                           0.3
# 5      Ukrainian        269      0.1*%                           0.2
# 6         Somali        336      0.1*%                           0.1
# 7        Tagalog        149      0.1*%                           0.1
# 8        Amharic        190      0.1*%                           0.1
# 9          Other      2,172      0.9*%

# %%
df.to_csv("pdf_covid_output1.csv")
df.to_excel("pdf_covid_output2.xlsx")

# %%
df2 = pd.read_csv("pdf_covid_output1.csv")
df2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-55b7eec8c557> in <module>
# ----> 1 df2 = pd.read_csv("pdf_covid_output1.csv")
#       2 df2
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File pdf_covid_output1.csv does not exist: 'pdf_covid_output1.csv'
