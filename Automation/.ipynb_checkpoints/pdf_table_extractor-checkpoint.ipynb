# %%
import camelot as cm
import pandas as pd
import seaborn as sns

# %%
input_pdf = cm.read_pdf("COVID-19MorbidityMortalityRaceEthnicityLanguageWAState.pdf", flavor = "stream", pages = "31")
input_pdf
# Out:
# <TableList n=1>

# %%
for n in input_pdf:
    print(n)
# Out:
# <Table shape=(21, 4)>

# %%
input_pdf[0].df
# Out:
#                                                     0                       1  \
# 0   Table 4. Confirmed or probable COVID-19 case c...
# 1                                     language spoken
# 2
# 3
# 4                                            Language  Case Count  % of Cases
# 5
# 6
# 7                                           All Cases                 631,023
# 8                                    Unknown Language                 400,072
# 9                                      Known Language                 230,951
# 10                                            English                 191,905
# 11                                            Spanish                  32,665
# 12                                        Marshallese                     333
# 13                                         Vietnamese                   1,134
# 14                                            Russian                   1,403
# ...

# %%
df = input_pdf[0].df.loc[11:21, 0:3]
df = df.reset_index(drop = True)
df.columns = ["Language","Case Count","% of Cases","% Limited English Proficiency"]
df
# Out:
#         Language Case Count % of Cases % Limited English Proficiency
# 0        Spanish     32,665     14.1*%                           6.4
# 1    Marshallese        333      0.1*%                           0.1
# 2     Vietnamese      1,134      0.5*%                           0.5
# 3        Russian      1,403      0.6*%                           0.3
# 4  Chinese (all)        395      0.2*%                           0.3
# 5      Ukrainian        269      0.1*%                           0.2
# 6         Somali        336      0.1*%                           0.1
# 7        Tagalog        149      0.1*%                           0.1
# 8        Amharic        190      0.1*%                           0.1
# 9          Other      2,172      0.9*%

# %%
df.to_csv("pdf_covid_output1.csv")
df.to_excel("pdf_covid_output2.xlsx")

# %%
df2 = pd.read_csv("pdf_covid_output1.csv")
df2
# Out:
#    Unnamed: 0       Language Case Count % of Cases  \
# 0           0        Spanish     32,665     14.1*%
# 1           1    Marshallese        333      0.1*%
# 2           2     Vietnamese      1,134      0.5*%
# 3           3        Russian      1,403      0.6*%
# 4           4  Chinese (all)        395      0.2*%
# 5           5      Ukrainian        269      0.1*%
# 6           6         Somali        336      0.1*%
# 7           7        Tagalog        149      0.1*%
# 8           8        Amharic        190      0.1*%
# 9           9          Other      2,172      0.9*%
#
#    % Limited English Proficiency
# 0                            6.4
# 1                            0.1
# 2                            0.5
# 3                            0.3
# 4                            0.3
# 5                            0.2
# 6                            0.1
# 7                            0.1
# 8                            0.1
# 9                            NaN

# %%
sns.barplot(x = "Language", y = "Case Count", data = df2);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ba5bc7dbf4b2> in <module>
# ----> 1 sns.barplot(x = "Language", y = "Case Count", data = df2);
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3142             ax=None, **kwargs):
#    3143
# -> 3144     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3145                           estimator, ci, n_boot, units, seed,
#    3146                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...
