# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
from matplotlib import pyplot as plt

# %%
url = 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population'
#req = requests.get(url)
#soup = bs(req.content)
#table = soup.select('.wikitable.sortable')
df = pd.read_html(url)

df[0].to_csv('countries_by_population.csv')

# %%
data = pd.read_csv('countries_by_population.csv')
for i in data.Country[2:]:
    country = data[data.Country == i]
    pop = countr.Population
    plt.plot(pop/ 10**6, 'o')
plt.xlabel('Position')
plt.ylabel('Millions of People')
plt.title('Population by Country without China and India')
plt.show()

# %%
for i in data.Country:
    arg = data[data.Country == i]
    pop = arg.Population
    plt.plot(pop/ 10**6, 'o')
plt.xlabel('Position')
plt.ylabel('Millions of People')
plt.title('Population by Country')
plt.show()

# %%
url1 = 'https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_and_territory'
df = pd.read_html(url1)
df[1].to_csv('Countries_COVID.csv')
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.read_csv('Countries_COVID.csv')
for i in data.Location[1:]:
    country = data[data.Location == i]
    cases = country.Cases
    plt.plot(i,int(cases)/10**6, 'o')
plt.xticks([])
plt.show()
